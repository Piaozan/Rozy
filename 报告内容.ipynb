# %%
from IPython.display import Image

# %% [markdown]
# # 基础信息

# %%
Image("./picture/basic_info.png")

# %% [markdown]
# - 通过以上四个视频得出，Rozy的影响力显著。整体来看，这些视频的播放量、点赞数和评论数都较高，显示出Rozy在社交媒体上具有较高的关注度和受欢迎程度。并且，第二部广告相较于第一部广告，更受欢迎：从播放量、点赞数和评论数来看，第二部广告《现在马上！Ask me》相较于第一部广告《给生活增添惊喜》，更受到观众的喜爱。这可能说明在广告形式和内容方面的创新以及Rozy形象的逐步完善，得到了市场的认可。
# - 其次，插曲视频表现优于广告视频。从数据上看，《给生活增添惊喜》广告插曲《Fly So Higher》的播放量、点赞数和评论数均高于原广告视频；同样，《现在马上！Ask me》插曲《Ask me》的播放量也高于广告视频本身。这说明广告插曲的创意及音乐表现力可能更吸引观众，受到了更广泛的关注和喜爱。
# - 同时，Rozy的环保品牌形象受到关注：新韩生命品牌方表示，音源收益将捐赠给环保组织，这与Rozy及品牌双方的环保品牌意识相契合。通过这样的举措，Rozy的形象得到了提升，也进一步拓展了她的粉丝基础。

# %% [markdown]
# # 评论语言

# %%
Image("./picture/lang.png")

# %% [markdown]
# - 评论语言主要为韩语（1884条），其次是英语（44条）以及德语（3条）等其他十种语言。
# - 从中可知，Rozy在韩国市场占据主导地位。评论中韩语占据绝大多数（1884条），显示出Rozy在韩国市场具有较高的关注度和受欢迎程度。这表明Rozy在韩国本土市场的营销策略和品牌传播取得了显著成果。
# - 英语评论占据次要地位。在所有评论中，英语评论数量次于韩语（44条），这意味着Rozy的影响力不仅局限于韩国市场，还拓展到了国际市场。英语评论的存在表明Rozy在全球范围内已经引起了一定程度的关注，这对于她的未来国际化发展具有积极意义。并且，多语言评论反映文化多样性。尽管德语评论数量较少（3条），但其存在仍表明Rozy在多元文化背景下的传播潜力。随着Rozy品牌的进一步发展和推广，她在全球各地区的影响力有望继续扩大，吸引更多不同国家和地区的关注。

# %% [markdown]
# # 评论点赞数

# %%
Image("./picture/like.png")

# %% [markdown]
# - 第一，音乐创作受到欢迎。评论中多次提及歌曲《Fly So Higher》，并表现出对音乐作品的喜爱。观众对歌曲产生了强烈的兴趣，甚至联系了作曲家和品牌方以获取更多关于音乐的信息。这表明音乐创作在虚拟网红Rozy的广告和品牌推广中发挥了关键作用。
# - 第二，观众对虚拟形象的认知和好奇心。评论中很多人表示对Rozy虚拟形象的好奇和惊讶，有的观众在观看广告时认为代言人的外观有点与众不同，有的甚至以为是修图过度。这些评论反映出观众对虚拟形象的认知度逐渐提高，对此类角色产生了兴趣。
# - 第三，观众对技术发展的关注。评论中提及了随着技术的发展，虚拟形象将变得越来越逼真，人眼将无法区分。这表明观众已经开始关注虚拟形象背后的技术发展，以及可能对现实生活产生的影响。
# - 第四，Rozy广告插曲视频受到更多关注。由于排名前十的评论都来自于广告插曲《Fly So Higher》的视频，这表明相较于其他三个视频，该插曲视频受到了更多观众的喜爱。这进一步证实了音乐创作在Rozy品牌推广中的重要地位。
# - 通过以上内容得出，Rozy的广告插曲视频受到观众的热烈欢迎，音乐创作在她的品牌推广中起到了关键作用。同时，观众对Rozy虚拟形象产生了好奇心，并对背后的技术发展表现出关注。这些反馈有助于了解观众对虚拟网红的接受程度，为未来的营销策略提供参考。

# %% [markdown]
# # 关键词

# %%
Image("./picture/word.png")

# %% [markdown]
# - 第一，歌曲因素。观众对“歌曲”的关注度非常高，“歌曲”、“MV”、“舞蹈”、“音源”、“歌词”和“旋律”等与音乐相关的关键词都进入了前二十名。这表明观众对广告中的音乐非常喜爱，音乐为广告带来了很高的观赏价值。
# - 第二，品牌和广告效果。“新韩生命”、“广告”、“视频”等关键词的高频次数显示出观众对品牌和广告的关注度较高，广告的推广效果显著。
# - 第三，虚拟网红Rozy。关键词中有“Rozy”、“虚拟”、“模特/代言”等词语，虽然排名相对较低，但仍能看出观众对虚拟网红Rozy的兴趣。Rozy作为虚拟代言人成功吸引了观众的目光，为广告带来了话题性。
# - 第四，观众情感反应。观众对广告的评价普遍积极，如“真的”、“支持”、“感觉”、“情绪”等词语都反映出观众对广告的积极情感反应。此外，能量这一关键词也暗示了广告在传达品牌形象时成功传递了积极的能量，引起了观众的共鸣。

# %% [markdown]
# # 情感倾向

# %%
Image("./picture/score.png")

# %% [markdown]
# - 最低情感分数为-8.11，表示评论中存在一定程度的负面反应。然而，这个最低分数并不能代表整体评论的情感倾向。
# - 最高情感分数为23.87，表示评论中的一部分观众对广告有很高的正面评价。同样，这个最高分数也不能代表整体评论的情感倾向。
# - 平均情感分数为1.39，意味着整体评论的情感倾向呈现正面。虽然平均值可以反映整体评论的情感倾向，但它不能描述具体的分布情况。
# - 中位数情感分数为0.92，反映了整体评论中位于中间的情感评分。与平均情感分数一样，中位数情感分数也呈现正面，这表明整体评论呈现出正面评价。
# - Rozy代言的新韩生命广告视频在评论中得到了较多的正面评价。平均情感分数和中位数情感分数都为正，说明大多数评论对广告持有正面看法。然而，也可以从最低情感分数和最高情感分数中看出，评论中仍然存在一定的负面评价。
